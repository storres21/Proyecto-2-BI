# %%
import pandas as pd
# Para preparar los datos
from sklearn.preprocessing import LabelEncoder
# Para crear el arbol de decisión 
from sklearn.tree import DecisionTreeClassifier 
# Para usar KNN como clasificador
from sklearn.neighbors import KNeighborsClassifier
# Para realizar la separación del conjunto de aprendizaje en entrenamiento y test.
from sklearn.model_selection import train_test_split
# Para evaluar el modelo
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, f1_score, accuracy_score

# Versiones anteriores a 1.2 de sklearn: from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import pickle

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay, precision_score, recall_score, f1_score
from sklearn import tree
from unidecode import unidecode

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.discriminant_analysis import StandardScaler
from sklearn.ensemble import RandomForestClassifier
# Para búsqueda de hiperparámetros
from sklearn.model_selection import GridSearchCV
# Para la validación cruzada
from sklearn.model_selection import KFold 
#Librerías para la visualización
import matplotlib.pyplot as plt
# Seaborn
import seaborn as sns 
from sklearn import tree
import sklearn as sklearn

import scipy.stats as stats
# %matplotlib inline

# %% [markdown]
# factores ambientales: NVCBP15D (contaminación del aire), NVCBP15F (generacion y manejo inadecuado de basuras), NVCBP11C (hay alcantarillado)
#
# condicones fisicas del hogar: NVCBP11AA(estrato), NVCBP8A(humedad), NVCBP8G (hay ventilación), NVCBP11B(hay acueducto) NVCBP13(material de los pisos), COD_UPZ(upz), CLASE (clase de), NVCBP15H(insectos => rural)
#
#
#
# DIRECTORIO (identificador de la vivienda)
# NPCFP14F (tiene enfermedades respiratorias)
#
#
#
#
# NVCBP15H(insectos => rural)

# %%
dfA2017 = pd.read_csv('data2017/Identificacion ( Capitulo A)/Identificacion ( Capitulo A).csv', encoding="ISO-8859-1", delimiter=';')
dfA2021 = pd.read_csv('data2021/Identificacion (Capitulo A)/Identificación (Capítulo A).csv', encoding="ISO-8859-1", delimiter=';')
dfB2017 = pd.read_csv('data2017/Datos de la vivenda y su entorno  ( Capitulo B)/Datos de la vivenda y su entorno  ( Capitulo B).csv', encoding="ISO-8859-1", delimiter=';')
dfB2021 = pd.read_csv('data2021/Datos de la vivenda y su entorno (Capitulo B)/Datos de la vivenda y su entorno (Capítulo B).csv', encoding="ISO-8859-1", delimiter=';')
dfC2017 = pd.read_csv('data2017/Condiciones habitacionales del hogar   (Capitulo C)/Condiciones habitacionales del hogar   (Capitulo C).csv', encoding="ISO-8859-1", delimiter=';')
dfC2021 = pd.read_csv('data2021/Condiciones habitacionales del hogar (Capitulo C)/Condiciones habitacionales del hogar (Capítulo C).csv', encoding="ISO-8859-1", delimiter=';')
dfF2017 = pd.read_csv('data2017/Salud ( Capitulo F)/Salud ( Capitulo F).csv', encoding="ISO-8859-1", delimiter=';')
dfF2021 = pd.read_csv('data2021/Salud (Capitulo F)/Salud (Capítulo F).csv', encoding="ISO-8859-1", delimiter=';')
# Out:
# /var/folders/c3/74tsbvcd7f59g59y1gww3qk40000gn/T/ipykernel_86402/3519749053.py:5: DtypeWarning: Columns (68,69,70,123,124) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfC2017 = pd.read_csv('data2017/Condiciones habitacionales del hogar   (Capitulo C)/Condiciones habitacionales del hogar   (Capitulo C).csv', encoding="ISO-8859-1", delimiter=';')
# /var/folders/c3/74tsbvcd7f59g59y1gww3qk40000gn/T/ipykernel_86402/3519749053.py:6: DtypeWarning: Columns (4,25,30,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfC2021 = pd.read_csv('data2021/Condiciones habitacionales del hogar (Capitulo C)/Condiciones habitacionales del hogar (Capítulo C).csv', encoding="ISO-8859-1", delimiter=';')
# /var/folders/c3/74tsbvcd7f59g59y1gww3qk40000gn/T/ipykernel_86402/3519749053.py:7: DtypeWarning: Columns (112) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
print(dfA2017.shape)
print(dfA2021.shape)
# Out:
# (107218, 12)
# (106467, 11)

# %%
print(dfB2017.shape)
print(dfB2021.shape)
# Out:
# (107218, 51)
# (106467, 63)

# %%
print(dfC2017.shape)
print(dfC2021.shape)
# Out:
# (109111, 137)
# (107119, 142)

# %%
print(dfF2017.shape)
print(dfF2021.shape)
# Out:
# (319952, 113)
# (292281, 135)

# %%
print(dfA2017.columns)
# Out:
# Index(['ï»¿DIRECTORIO', 'SECUENCIA', 'SECUENCIA_P', 'ORDEN', 'NVCAP99',
#        'DPTOMPIO', 'CLASE', 'TOT_HOG_COMP', 'FEX_C', 'LOCALIDAD_TEX',
#        'COD_UPZ', 'CODLOCALIDAD'],
#       dtype='object')

# %%
dfA2017.rename(columns={'ï»¿DIRECTORIO': 'DIRECTORIO'}, inplace=True)

# %%
dfA2017.rename(columns={'LOCALIDAD_TEX': 'LOCALIDAD'}, inplace=True)

# %%
display(dfA2017[['DIRECTORIO','LOCALIDAD', 'CLASE']].sample(5))
# Out:
#        DIRECTORIO      LOCALIDAD  CLASE
# 7027       111872        USAQUEN      1
# 66734      228964                     1
# 95446      279708           SUBA      1
# 78115      248453    TEUSAQUILLO      1
# 62011      222369  PUENTE ARANDA      1

# %%
dfA2017new = dfA2017[['DIRECTORIO','LOCALIDAD','CLASE']]

# %%
display(dfA2017new.sample(5))
# Out:
#        DIRECTORIO    LOCALIDAD  CLASE
# 67748      230464  TEUSAQUILLO      1
# 63460      224728                   1
# 7049       111894      USAQUEN      1
# 73379      238051                   1
# 78113      248451    CHAPINERO      1

# %%
# Para var cuantos duplicados hay
duplicates = dfA2017.duplicated()
num_duplicates = duplicates.sum()
print("Number of duplicates: ", num_duplicates)
# Out:
# Number of duplicates:  0

# %%
print(dfA2021.columns)
# Out:
# Index(['DIRECTORIO', 'DPTO', 'MPIO', 'CLASE', 'COD_LOCALIDAD',
#        'NOMBRE_LOCALIDAD', 'COD_UPZ_GRUPO', 'NOMBRE_UPZ_GRUPO', 'ESTRATO2021',
#        'NOMBRE_ESTRATO', 'FEX_C'],
#       dtype='object')

# %%
dfA2021.rename(columns={'NOMBRE_LOCALIDAD': 'LOCALIDAD'}, inplace=True)

# %%
display(dfA2021[['DIRECTORIO','LOCALIDAD', 'CLASE']].sample(5))
# Out:
#        DIRECTORIO           LOCALIDAD  CLASE
# 2320     323766.0                 NaN      2
# 46880   1038188.0                 NaN      1
# 1271    3006200.0        Los Mártires      1
# 10131    334983.0  Rafael Uribe Uribe      1
# 98353   1873705.0                 NaN      1

# %%
dfA2021new = dfA2021[['DIRECTORIO','LOCALIDAD', 'CLASE']]

# %%
display(dfA2021new.sample(5))
# Out:
#        DIRECTORIO      LOCALIDAD  CLASE
# 63477   1102198.0           Bosa      1
# 45320   1035595.0  San Cristóbal      1
# 87659   1158858.0           Usme      1
# 30244   1001282.0        Kennedy      1
# 87962   1159206.0            NaN      1

# %%
# Para var cuantos duplicados hay
duplicates = dfA2021.duplicated()
num_duplicates = duplicates.sum()
print("Number of duplicates: ", num_duplicates)
# Out:
# Number of duplicates:  0

# %%
print(dfB2017.columns)
# Out:
# Index(['ï»¿DIRECTORIO', 'SECUENCIA', 'SECUENCIA_P', 'ORDEN', 'NVCBP1',
#        'NVCBP2', 'NVCBP3', 'NVCBP4', 'NVCBP5', 'NVCBP6', 'NVCBP7', 'NVCBP8A',
#        'NVCBP8B', 'NVCBP8C', 'NVCBP8D', 'NVCBP8E', 'NVCBP8F', 'NVCBP8G',
#        'NVCBP8H', 'NVCBP8I', 'NVCBP8J', 'NVCBP9', 'NVCBP10', 'NVCBP11A',
#        'NVCBP11AA', 'NVCBP11B', 'NVCBP11C', 'NVCBP11D', 'NVCBP11DA', 'NVCBP12',
#        'NVCBP13', 'NVCBP14A', 'NVCBP14B', 'NVCBP14C', 'NVCBP14D', 'NVCBP14E',
#        'NVCBP14F', 'NVCBP14G', 'NVCBP14H', 'NVCBP14I', 'NVCBP14J', 'NVCBP14K',
#        'NVCBP15A', 'NVCBP15B', 'NVCBP15C', 'NVCBP15D', 'NVCBP15E', 'NVCBP15F',
#        'NVCBP15G', 'NVCBP15H', 'FEX_C'],
#       dtype='object')

# %%
dfB2017.rename(columns={'ï»¿DIRECTORIO': 'DIRECTORIO'}, inplace=True)

# %%
display(dfB2017[['DIRECTORIO','NVCBP15D', 'NVCBP15F', 'NVCBP11C', 'NVCBP11AA', 'NVCBP8A', 'NVCBP8G', 'NVCBP11B', 'NVCBP13', 'NVCBP15H' ]].sample(5))
# Out:
#        DIRECTORIO  NVCBP15D  NVCBP15F  NVCBP11C NVCBP11AA  NVCBP8A  NVCBP8G  \
# 2107       104099         2         2         1         3        9        9
# 38808      165255         2         1         1         2        1        1
# 12186      128107         1         1         1         1        2        2
# 33954      159520         1         2         1         2        2        2
# 88040      262755         2         1         1         4        2        2
#
#        NVCBP11B  NVCBP13  NVCBP15H
# 2107          1        4         2
# 38808         1        6         1
# 12186         1        4         1
# 33954         1        4         1
# 88040         1        4         2

# %%
dfB2017new = dfB2017[['DIRECTORIO','NVCBP15D', 'NVCBP15F', 'NVCBP11C', 'NVCBP11AA', 'NVCBP8A', 'NVCBP8G', 'NVCBP11B', 'NVCBP13', 'NVCBP15H' ]]

# %%
display(dfB2017new.sample(5))
# Out:
#         DIRECTORIO  NVCBP15D  NVCBP15F  NVCBP11C NVCBP11AA  NVCBP8A  NVCBP8G  \
# 88772       265679         1         1         1         6        2        2
# 15320       134059         2         2         1         2        1        2
# 23489       142923         2         2         1         3        2        2
# 100895      292806         2         2         1         2        2        2
# 105891      307214         1         2         1         4        1        2
#
#         NVCBP11B  NVCBP13  NVCBP15H
# 88772          1        4         2
# 15320          1        4         2
# 23489          1        4         2
# 100895         1        4         2
# 105891         1        4         2

# %%
# Para var cuantos duplicados hay
duplicates = dfB2017.duplicated()
num_duplicates = duplicates.sum()
print("Number of duplicates: ", num_duplicates)
# Out:
# Number of duplicates:  0

# %%
print(dfB2021.columns)
# Out:
# Index(['DIRECTORIO', 'NVCBP1', 'NVCBP2', 'NVCBP3', 'NVCBP4', 'NVCBP5',
#        'NVCBP6', 'NVCBP7', 'NVCBP8A', 'NVCBP8B', 'NVCBP8C', 'NVCBP8D',
#        'NVCBP8E', 'NVCBP8F', 'NVCBP8G', 'NVCBP8H', 'NVCBP8I', 'NVCBP8J',
#        'NVCBP9', 'NVCBP9A1', 'NVCBP9A2', 'NVCBP9A3', 'NVCBP9A4', 'NVCBP10',
#        'NVCBP11A', 'NVCBP11AA', 'NVCBP11B', 'NVCBP11C', 'NVCBP11D',
#        'NVCBP11DA', 'NVCBP12', 'NVCBP13', 'NVCBP14A', 'NVCBP14B', 'NVCBP14C',
#        'NVCBP14D', 'NVCBP14E', 'NVCBP14L', 'NVCBP14F', 'NVCBP14G', 'NVCBP14H',
#        'NVCBP14I', 'NVCBP14J', 'NVCBP14K', 'NVCBP15A', 'NVCBP15B', 'NVCBP15C',
#        'NVCBP15D', 'NVCBP15E', 'NVCBP15F', 'NVCBP15G', 'NVCBP15H', 'NVCBP15I',
#        'NVCBP15J', 'NVCBP15K', 'NVCBP15L', 'NVCBP15M', 'NVCBP16A1',
#        'NVCBP16A2', 'NVCBP16A3', 'NVCBP16A4', 'NVCBP16', 'FEX_C'],
#       dtype='object')

# %%
display(dfB2021[['DIRECTORIO','NVCBP15D', 'NVCBP15F', 'NVCBP11C', 'NVCBP11AA', 'NVCBP8A', 'NVCBP8G', 'NVCBP11B', 'NVCBP13', 'NVCBP15H' ]].sample(5))
# Out:
#        DIRECTORIO  NVCBP15D  NVCBP15F  NVCBP11C  NVCBP11AA  NVCBP8A  NVCBP8G  \
# 64565   1103697.0         1         2         1        5.0        2        2
# 6566     330418.0         2         2         1        2.0        1        2
# 49862   1042927.0         1         2         1        4.0        2        2
# 30924   1002589.0         1         2         1        2.0        1        2
# 1001    3006151.0         1         2         1        3.0        1        1
#
#        NVCBP11B  NVCBP13  NVCBP15H
# 64565         1        4         2
# 6566          1        4         2
# 49862         1        4         2
# 30924         1        4         2
# 1001          1        4         2

# %%
dfB2021new = dfB2021[['DIRECTORIO','NVCBP15D', 'NVCBP15F', 'NVCBP11C', 'NVCBP11AA', 'NVCBP8A', 'NVCBP8G', 'NVCBP11B', 'NVCBP13', 'NVCBP15H' ]]

# %%
display(dfB2021new.sample(5))
# Out:
#         DIRECTORIO  NVCBP15D  NVCBP15F  NVCBP11C  NVCBP11AA  NVCBP8A  NVCBP8G  \
# 19434     559910.0         2         1         2        1.0        1        2
# 102161   3000058.0         2         2         1        6.0        2        2
# 84591    1155255.0         2         2         1        4.0        2        2
# 85472    1156434.0         2         2         1        6.0        2        2
# 10328     335522.0         1         1         1        2.0        2        2
#
#         NVCBP11B  NVCBP13  NVCBP15H
# 19434          1        7         1
# 102161         1        4         2
# 84591          1        4         2
# 85472          1        4         2
# 10328          1        5         2

# %%
# Para var cuantos duplicados hay
duplicates = dfB2021.duplicated()
num_duplicates = duplicates.sum()
print("Number of duplicates: ", num_duplicates)
# Out:
# Number of duplicates:  0

# %%
print(dfF2017.columns)
# Out:
# Index(['ï»¿DIRECTORIO_PER', 'DIRECTORIO_HOG', 'DIRECTORIO', 'SECUENCIA_P',
#        'ORDEN', 'NPCFP1', 'NPCFP2', 'NPCFP3', 'NPCFP4A', 'NPCFP4B',
#        ...
#        'NPCFP40E', 'NPCFP40F', 'NPCFP40', 'NPCFP41', 'NPCFP42', 'NPCFP43',
#        'NPCFP43A', 'NPCFP44', 'NPCFP45', 'FEX_C'],
#       dtype='object', length=113)

# %%
display(dfF2017[['DIRECTORIO','NPCFP14B']].sample(5))
# Out:
#         DIRECTORIO  NPCFP14B
# 227881      238401         2
# 23303       112316         2
# 187566      196749         2
# 108089      159817         2
# 262625      259750         2

# %%
dfF2017['ENFERMEDADES_R'] = dfF2017.groupby('DIRECTORIO')['NPCFP14B'].transform(lambda x: 1 if (x == 1).any() else 2)

# Seleccionar solo las columnas 'vivienda' y 'salud_vivienda'
df_resultado = dfF2017[['DIRECTORIO', 'ENFERMEDADES_R']].drop_duplicates().reset_index(drop=True)

# %%
display(dfF2017[['DIRECTORIO','ENFERMEDADES_R']].sample(5))
# Out:
#         DIRECTORIO  ENFERMEDADES_R
# 228354      238819               2
# 15295       108874               2
# 182788      195086               2
# 94741       154640               2
# 96138       155276               2

# %%
dfF2017new = df_resultado

# %%
display(dfF2017new.sample(5))
# Out:
#        DIRECTORIO  ENFERMEDADES_R
# 69373      232744               2
# 27917      152395               1
# 61165      221214               1
# 17545      136466               2
# 84383      256953               2

# %%
# Para var cuantos duplicados hay
duplicates = dfF2017.duplicated()
num_duplicates = duplicates.sum()
print("Number of duplicates: ", num_duplicates)
# Out:
# Number of duplicates:  0

# %%
print(dfF2021.columns)
# Out:
# Index(['DIRECTORIO', 'DIRECTORIO_HOG', 'DIRECTORIO_PER', 'SECUENCIA_P',
#        'ORDEN', 'NPCFP1', 'NPCFP2', 'NPCFP3', 'NPCFP4A', 'NPCFP4B',
#        ...
#        'NPCFP44', 'NPCFP45', 'NPCFP46', 'NPCFP47A', 'NPCFP47B', 'NPCFP47C',
#        'NPCFP47D', 'NPCFP47E', 'NPCFP47F', 'FEX_C'],
#       dtype='object', length=135)

# %%
display(dfF2021[['DIRECTORIO','NPCFP14F']].sample(5))
# Out:
#         DIRECTORIO  NPCFP14F
# 275152   2192983.0         2
# 163362   1065185.0         2
# 8156      327419.0         2
# 17115     331724.0         2
# 141098   1046217.0         2

# %%
dfF2021['ENFERMEDADES_R'] = dfF2021.groupby('DIRECTORIO')['NPCFP14F'].transform(lambda x: 1 if (x == 1).any() else 2)

# Seleccionar solo las columnas 'vivienda' y 'salud_vivienda'
df_resultado2 = dfF2021[['DIRECTORIO', 'ENFERMEDADES_R']].drop_duplicates().reset_index(drop=True)

# %%
dfF2021new = df_resultado2

# %%
display(dfF2021new.sample(5))
# Out:
#        DIRECTORIO  ENFERMEDADES_R
# 11050    338515.0               1
# 70442   1128106.0               2
# 42660   1034680.0               2
# 95044   1871759.0               2
# 54188   1054753.0               2

# %%
# Para var cuantos duplicados hay
duplicates = dfF2021new.duplicated()
num_duplicates = duplicates.sum()
print("Number of duplicates: ", num_duplicates)
# Out:
# Number of duplicates:  0

# %%
df20171= pd.merge(dfA2017new, dfB2017new,on='DIRECTORIO')

# %%
df2017= pd.merge(df20171, dfF2017new,on='DIRECTORIO')

# %%
print(df2017.columns)
# Out:
# Index(['DIRECTORIO', 'LOCALIDAD', 'CLASE', 'NVCBP15D', 'NVCBP15F', 'NVCBP11C',
#        'NVCBP11AA', 'NVCBP8A', 'NVCBP8G', 'NVCBP11B', 'NVCBP13', 'NVCBP15H',
#        'ENFERMEDADES_R'],
#       dtype='object')

# %%
df20211= pd.merge(dfA2021new, dfB2021new,on='DIRECTORIO')

# %%
df2021= pd.merge(df20211, dfF2021new,on='DIRECTORIO')

# %%
print(df2021.columns)
# Out:
# Index(['DIRECTORIO', 'LOCALIDAD', 'CLASE', 'NVCBP15D', 'NVCBP15F', 'NVCBP11C',
#        'NVCBP11AA', 'NVCBP8A', 'NVCBP8G', 'NVCBP11B', 'NVCBP13', 'NVCBP15H',
#        'ENFERMEDADES_R'],
#       dtype='object')

# %% [markdown]
# # Limpieza

# %% [markdown]
# ## Manejo de valores nulos

# %% [markdown]
# ### DF2017

# %%
df_porcentajes = (100*df2017.isna().sum()/len(df2017)).to_frame()
df_porcentajes.sort_values(0, ascending = False)
# Out:
#                   0
# DIRECTORIO      0.0
# LOCALIDAD       0.0
# CLASE           0.0
# NVCBP15D        0.0
# NVCBP15F        0.0
# NVCBP11C        0.0
# NVCBP11AA       0.0
# NVCBP8A         0.0
# NVCBP8G         0.0
# NVCBP11B        0.0
# NVCBP13         0.0
# NVCBP15H        0.0
# ENFERMEDADES_R  0.0

# %%
df2017.sample(10)
# Out:
#        DIRECTORIO       LOCALIDAD  CLASE  NVCBP15D  NVCBP15F  NVCBP11C  \
# 4153       107800            SUBA      1         1         2         1
# 38863      165312                      1         2         2         1
# 90457      268796                      1         2         2         1
# 86287      260203            SUBA      1         2         2         1
# 45076      172637        FONTIBON      1         2         2         1
# 44549      172004  BARRIOS UNIDOS      1         2         2         1
# 74826      240193        SANTA FE      1         2         2         1
# 75422      241013                      1         2         1         1
# 14000      130587                      1         2         2         1
# 21740      141061     TEUSAQUILLO      1         2         2         1
#
#       NVCBP11AA  NVCBP8A  NVCBP8G  NVCBP11B  NVCBP13  NVCBP15H  ENFERMEDADES_R
# 4153          5        1        2         1        2         2               2
# ...

# %%
# Calcula el porcentaje de filas con valores vacíos por columna
porcentaje_filas_vacias = (df2017 == ' ').mean() * 100

# Crea un nuevo DataFrame con la información de los porcentajes de filas vacías
filas_vacias_info = pd.DataFrame({'Columna': porcentaje_filas_vacias.index, 'Porcentaje Filas Vacías': porcentaje_filas_vacias.values})

# Muestra el nuevo DataFrame ordenado por el porcentaje de filas vacías de forma descendente
print(filas_vacias_info.sort_values(by='Porcentaje Filas Vacías', ascending=False))
# Out:
#            Columna  Porcentaje Filas Vacías
# 1        LOCALIDAD                29.398982
# 6        NVCBP11AA                 0.179074
# 0       DIRECTORIO                 0.000000
# 2            CLASE                 0.000000
# 3         NVCBP15D                 0.000000
# 4         NVCBP15F                 0.000000
# 5         NVCBP11C                 0.000000
# 7          NVCBP8A                 0.000000
# 8          NVCBP8G                 0.000000
# 9         NVCBP11B                 0.000000
# 10         NVCBP13                 0.000000
# 11        NVCBP15H                 0.000000
# 12  ENFERMEDADES_R                 0.000000

# %%
df2017['NVCBP11AA'].describe()
# Out:
# count     107218
# unique        10
# top            2
# freq       44695
# Name: NVCBP11AA, dtype: object

# %%
df2017['NVCBP11AA'] = df2017['NVCBP11AA'].replace(' ', np.nan)
#elimino los valores nulos
df2017=df2017.dropna(subset=['NVCBP11AA'])

# %%
df2017['LOCALIDAD'] = df2017['LOCALIDAD'].replace(' ', 'desconocido')

# %%
valores_unicos = df2017['NVCBP11AA'].unique()
print(valores_unicos)
# Out:
# ['2' '3' '6' '1' '4' '5' '0' '9' '8']

# %%
df2017['NVCBP11AA'] = df2017['NVCBP11AA'].astype(int)

# %%
valores_unicos = df2017['NVCBP11AA'].unique()
print(valores_unicos)
# Out:
# [2 3 6 1 4 5 0 9 8]

# %%
# Calcula el porcentaje de filas con valores vacíos por columna
porcentaje_filas_vacias = (df2017 == ' ').mean() * 100

# Crea un nuevo DataFrame con la información de los porcentajes de filas vacías
filas_vacias_info = pd.DataFrame({'Columna': porcentaje_filas_vacias.index, 'Porcentaje Filas Vacías': porcentaje_filas_vacias.values})

# Muestra el nuevo DataFrame ordenado por el porcentaje de filas vacías de forma descendente
print(filas_vacias_info.sort_values(by='Porcentaje Filas Vacías', ascending=False))
# Out:
#            Columna  Porcentaje Filas Vacías
# 0       DIRECTORIO                      0.0
# 1        LOCALIDAD                      0.0
# 2            CLASE                      0.0
# 3         NVCBP15D                      0.0
# 4         NVCBP15F                      0.0
# 5         NVCBP11C                      0.0
# 6        NVCBP11AA                      0.0
# 7          NVCBP8A                      0.0
# 8          NVCBP8G                      0.0
# 9         NVCBP11B                      0.0
# 10         NVCBP13                      0.0
# 11        NVCBP15H                      0.0
# 12  ENFERMEDADES_R                      0.0

# %% [markdown]
# ### DF2021

# %%
df2021.sample(10)
# Out:
#        DIRECTORIO           LOCALIDAD  CLASE  NVCBP15D  NVCBP15F  NVCBP11C  \
# 69483   1121356.0      Ciudad Bolívar      3         1         2         2
# 24359    990166.0                Suba      1         2         1         1
# 30825   1002223.0       San Cristóbal      1         2         2         1
# 33976   1013461.0             Usaquén      3         2         2         2
# 6291     329637.0  Rafael Uribe Uribe      1         2         2         1
# 29267   1000127.0                Bosa      1         1         1         1
# 79604   1147668.0                Suba      1         2         2         1
# 13082    338720.0             Kennedy      1         2         2         1
# 16370    343046.0      Ciudad Bolívar      1         2         2         1
# 58027   1060304.0      Antonio Nariño      1         2         2         1
#
#        NVCBP11AA  NVCBP8A  NVCBP8G  NVCBP11B  NVCBP13  NVCBP15H  \
# 69483        1.0        1        1         1        4         1
# ...

# %%
df_porcentajes = (100*df2021.isna().sum()/len(df2021)).to_frame()
df_porcentajes.sort_values(0, ascending = False)
# Out:
#                         0
# LOCALIDAD       18.750411
# NVCBP11AA        0.223543
# DIRECTORIO       0.000000
# CLASE            0.000000
# NVCBP15D         0.000000
# NVCBP15F         0.000000
# NVCBP11C         0.000000
# NVCBP8A          0.000000
# NVCBP8G          0.000000
# NVCBP11B         0.000000
# NVCBP13          0.000000
# NVCBP15H         0.000000
# ENFERMEDADES_R   0.000000

# %%
df2021=df2021.dropna(subset=['NVCBP11AA'])

# %%
df2021['LOCALIDAD'].fillna('desconocido', inplace=True)

# %%
df_porcentajes = (100*df2021.isna().sum()/len(df2021)).to_frame()
df_porcentajes.sort_values(0, ascending = False)
# Out:
#                   0
# DIRECTORIO      0.0
# LOCALIDAD       0.0
# CLASE           0.0
# NVCBP15D        0.0
# NVCBP15F        0.0
# NVCBP11C        0.0
# NVCBP11AA       0.0
# NVCBP8A         0.0
# NVCBP8G         0.0
# NVCBP11B        0.0
# NVCBP13         0.0
# NVCBP15H        0.0
# ENFERMEDADES_R  0.0

# %%
# Calcula el porcentaje de filas con valores vacíos por columna
porcentaje_filas_vacias = (df2021 == ' ').mean() * 100

# Crea un nuevo DataFrame con la información de los porcentajes de filas vacías
filas_vacias_info = pd.DataFrame({'Columna': porcentaje_filas_vacias.index, 'Porcentaje Filas Vacías': porcentaje_filas_vacias.values})

# Muestra el nuevo DataFrame ordenado por el porcentaje de filas vacías de forma descendente
print(filas_vacias_info.sort_values(by='Porcentaje Filas Vacías', ascending=False))
# Out:
#            Columna  Porcentaje Filas Vacías
# 0       DIRECTORIO                      0.0
# 1        LOCALIDAD                      0.0
# 2            CLASE                      0.0
# 3         NVCBP15D                      0.0
# 4         NVCBP15F                      0.0
# 5         NVCBP11C                      0.0
# 6        NVCBP11AA                      0.0
# 7          NVCBP8A                      0.0
# 8          NVCBP8G                      0.0
# 9         NVCBP11B                      0.0
# 10         NVCBP13                      0.0
# 11        NVCBP15H                      0.0
# 12  ENFERMEDADES_R                      0.0

# %% [markdown]
# ## Convertir todo al mismo formato

# %%
# Convertir columna de mayusculas a minusculas y quitar tildes
df2021['LOCALIDAD'] = df2021['LOCALIDAD'].apply(lambda x: unidecode(str(x)))
df2021['LOCALIDAD'] = df2021['LOCALIDAD'].str.lower()
df2017['LOCALIDAD'] = df2017['LOCALIDAD'].apply(lambda x: unidecode(str(x)))
df2017['LOCALIDAD'] = df2017['LOCALIDAD'].str.lower()

# %%
#convertir de float a entero
df2021['NVCBP11AA'] = df2021['NVCBP11AA'].astype(int)
df2021['DIRECTORIO'] = df2021['DIRECTORIO'].astype(int)

# %% [markdown]
# ## Duplicidad

# %%
# Para var cuantos duplicados hay
duplicates = df2017.duplicated()
num_duplicates = duplicates.sum()
print("Number of duplicates: ", num_duplicates)
# Out:
# Number of duplicates:  0

# %%
# Para var cuantos duplicados hay
duplicates = df2021.duplicated()
num_duplicates = duplicates.sum()
print("Number of duplicates: ", num_duplicates)
# Out:
# Number of duplicates:  0

# %% [markdown]
# ## Consistencia

# %%
df2017.describe()
# Out:
#           DIRECTORIO          CLASE       NVCBP15D       NVCBP15F  \
# count  107026.000000  107026.000000  107026.000000  107026.000000
# mean   198760.423710       1.039990       1.707828       1.840198
# std     59213.670758       0.276475       0.454763       0.366424
# min    101000.000000       1.000000       1.000000       1.000000
# 25%    147569.250000       1.000000       1.000000       2.000000
# 50%    184585.500000       1.000000       2.000000       2.000000
# 75%    251609.750000       1.000000       2.000000       2.000000
# max    317885.000000       3.000000       2.000000       2.000000
#
#             NVCBP11C      NVCBP11AA        NVCBP8A        NVCBP8G  \
# count  107026.000000  107026.000000  107026.000000  107026.000000
# mean        1.023929       2.596136       1.861267       2.057930
# std         0.152828       0.980336       0.928422       0.887658
# min         1.000000       0.000000       1.000000       1.000000
# ...

# %%
df2021.describe()
# Out:
#          DIRECTORIO          CLASE       NVCBP15D       NVCBP15F  \
# count  1.062290e+05  106229.000000  106229.000000  106229.000000
# mean   1.118331e+06       1.126444       1.745192       1.831364
# std    5.985875e+05       0.474325       0.435755       0.374432
# min    1.662380e+05       1.000000       1.000000       1.000000
# 25%    9.990010e+05       1.000000       1.000000       2.000000
# 50%    1.053688e+06       1.000000       2.000000       2.000000
# 75%    1.151105e+06       1.000000       2.000000       2.000000
# max    3.006812e+06       3.000000       2.000000       2.000000
#
#             NVCBP11C      NVCBP11AA        NVCBP8A        NVCBP8G  \
# count  106229.000000  106229.000000  106229.000000  106229.000000
# mean        1.053535       2.750106       1.816914       2.049723
# std         0.225099       1.117155       0.802527       0.781990
# min         1.000000       0.000000       1.000000       1.000000
# ...

# %% [markdown]
# ## Agregar año

# %%
df2017['ANIO'] = 2017
df2021['ANIO'] = 2021

# %%
df2017.sample(10)
# Out:
#        DIRECTORIO      LOCALIDAD  CLASE  NVCBP15D  NVCBP15F  NVCBP11C  \
# 29758      154429    desconocido      1         1         2         1
# 38349      164787           usme      1         2         2         1
# 39710      166353  puente aranda      1         2         2         1
# 35665      161311    desconocido      1         2         2         1
# 43571      170900           bosa      1         1         2         1
# 48453      178797       fontibon      1         2         2         1
# 26370      147109       fontibon      1         2         2         1
# 27919      152397           suba      1         2         1         1
# 84744      257344    desconocido      1         2         2         1
# 56260      190179           suba      1         2         2         1
#
#        NVCBP11AA  NVCBP8A  NVCBP8G  NVCBP11B  NVCBP13  NVCBP15H  \
# 29758          3        2        2         1        4         1
# 38349          2        2        2         1        4         2
# ...

# %%
df2021.sample(10)
# Out:
#        DIRECTORIO       LOCALIDAD  CLASE  NVCBP15D  NVCBP15F  NVCBP11C  \
# 50067     1042908        fontibon      1         2         2         1
# 179       3005074     teusaquillo      1         2         2         1
# 75516     1139528  ciudad bolivar      1         2         2         1
# 34043     1013547     desconocido      3         2         2         2
# 485       3005394         usaquen      1         2         1         1
# 11660      336947            bosa      1         2         2         1
# 64072     1102849            suba      1         1         1         1
# 63653     1102398            bosa      1         1         1         1
# 59303     1063509        engativa      1         2         2         1
# 50635     1043548         usaquen      1         1         2         1
#
#        NVCBP11AA  NVCBP8A  NVCBP8G  NVCBP11B  NVCBP13  NVCBP15H  \
# 50067          2        2        2         1        4         2
# ...

# %%
# Verificar si hay coincidencias en la columna 'Directorio'
coincidencias = df2017['DIRECTORIO'].isin(df2021['DIRECTORIO'])

# Mostrar las filas de df1 que tienen coincidencias
print(df2017[coincidencias])
# Out:
#        DIRECTORIO           LOCALIDAD  CLASE  NVCBP15D  NVCBP15F  NVCBP11C  \
# 39596      166238            fontibon      1         1         2         1
# 61828      222175            fontibon      1         2         2         1
# 65374      227359                suba      1         2         2         1
# 65377      227362                suba      1         2         2         1
# 67061      229508             usaquen      1         2         2         1
# 67250      229753             usaquen      1         2         2         1
# 69882      233394       san cristobal      1         2         2         1
# 69888      233400       san cristobal      1         2         2         1
# 70054      233578  rafael uribe uribe      1         1         2         1
# 70540      234183         desconocido      1         2         2         1
# 71050      234724         desconocido      1         1         2         1
# ...

# %%
fila_directorio_2017 = df2017[df2017['DIRECTORIO'] == 166238]

# Mostrar el resultado
print(fila_directorio_2017)

fila_directorio_2021 = df2021[df2021['DIRECTORIO'] == 166238]

# Mostrar el resultado  
print(fila_directorio_2021)
# Out:
#        DIRECTORIO LOCALIDAD  CLASE  NVCBP15D  NVCBP15F  NVCBP11C  NVCBP11AA  \
# 39596      166238  fontibon      1         1         2         1          2
#
#        NVCBP8A  NVCBP8G  NVCBP11B  NVCBP13  NVCBP15H  ENFERMEDADES_R  ANIO
# 39596        2        2         1        4         1               2  2017
#       DIRECTORIO  LOCALIDAD  CLASE  NVCBP15D  NVCBP15F  NVCBP11C  NVCBP11AA  \
# 1857      166238  chapinero      3         2         2         2          2
#
#       NVCBP8A  NVCBP8G  NVCBP11B  NVCBP13  NVCBP15H  ENFERMEDADES_R  ANIO
# 1857        2        2         2        4         2               2  2021

# %%
ruta_carpeta = 'data/'
nombre_archivo = 'data2017.csv'

df2017.to_csv(ruta_carpeta + nombre_archivo, index=False)

# %%
ruta_carpeta = 'data/'
nombre_archivo = 'data2021.csv'

df2021.to_csv(ruta_carpeta + nombre_archivo, index=False)
